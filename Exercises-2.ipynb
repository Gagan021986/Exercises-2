# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
titles= pd.read_csv('C:/Users/Hira singh/Downloads/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv("C:/Users/Hira singh/Desktop/cast.csv")
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
titles.columns
# Out:
# Index(['title', 'year'], dtype='object')

# %%
cast.columns
# Out:
# Index(['title', 'year', 'name', 'type', 'character', 'n'], dtype='object')

# %%
common_data=pd.concat([titles,cast],ignore_index=True)

# %%
movie_counts =common_data['title'].value_counts()

# %%
top_10_movies=movie_counts.head(10)
print(top_10_movies)
# Out:
# Around the World in Eighty Days       384
# 7 cajas                               192
# The Dark Knight Rises                 174
# The Ten Commandments                  170
# King Kong                             162
# The Buccaneer                         160
# Cockneys vs Zombies                   158
# Stuck on You                          154
# The Eschatrilogy: Book of the Dead    145
# Thelma                                142
# Name: title, dtype: int64

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
year= 'year'

# %%
movies_1930=(cast[ 'year']>=1930)

# %%
top_3_years =films_1930_year.head(3)
print(top_3_years)
# Out:
# 2016    10754
# 2015     8397
# 2017     8178
# Name: year, dtype: int64

# %% [markdown]
# ### Plot the number of films that have been released each decade over the history of cinema.

# %%
cast['decade']=(cast['year']//10)*10

# %%
movies_decade= cast['decade'].value_counts().sort_index()

# %%
plt.figure(figsize=(10,6))
plt.bar(movies_decade.index, movies_decade.values, width=8)
plt.title('Number of movies released each decade')
plt.xlabel('decade')
plt.ylabel('number of movies')
plt.show()

# %% [markdown]
# ### Plot the number of "Hamlet" films made each decade.

# %%
merged_data = pd.merge(titles,cast,on='title')

# %%
Hamlet_movies=merged_data[merged_data['title']=='Hamlet']

# %%
print(Hamlet_movies.columns)
# Out:
# Index(['title', 'year_x', 'year_y', 'name', 'type', 'character', 'n',
#        'decade'],
#       dtype='object')

# %%
Hamlet_movies['decade']=(Hamlet_movies['year_x']//10)*10
# Out:
# C:\Users\Hira singh\AppData\Local\Temp\ipykernel_24964\1420137427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hamlet_movies['decade']=(Hamlet_movies['year_x']//10)*10

# %%
decade_counts = Hamlet_movies['decade'].value_counts().sort_index()

# %%
decade_counts.plot(kind='bar',xlabel='Decade',ylabel= 'Number of the Hamlet',title ='Hamlet')
plt.show()

# %% [markdown]
# # only using cast file

# %%
Hamlet_movies = cast[cast['title']=='Hamlet']

# %%
Hamlet_movies['decade']=(Hamlet_movies['year'] // 10) * 10
# Out:
# C:\Users\Hira singh\AppData\Local\Temp\ipykernel_24964\2736682200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hamlet_movies['decade']=(Hamlet_movies['year'] // 10) * 10

# %%
decade_counts = Hamlet_movies['decade'].value_counts().sort_index()

# %%
decade_counts.plot(kind='bar',xlabel='Decade',ylabel= 'Number of the Hamlet',title ='Hamlet')
plt.show()

# %% [markdown]
# ### Plot the number of "Rustler" characters in each decade of the history of film.

# %%
Rustler=cast[cast['character']=='Rustler']

# %%
Rustler['decade']=(Rustler['year'] // 10) * 10
# Out:
# C:\Users\Hira singh\AppData\Local\Temp\ipykernel_24964\4008016204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Rustler['decade']=(Rustler['year'] // 10) * 10

# %%
decade_counts = Rustler['decade'].value_counts().sort_index()

# %%
decade_counts.plot(kind='bar',xlabel='Decade',ylabel= 'Number',title ='Rustler_character')
plt.show()

# %% [markdown]
# ### Plot the number of "Hamlet" characters each decade.

# %%
Hamlet=cast[cast['character']=='Hamlet']

# %%
Hamlet['decade']=(Hamlet['year'] // 10) * 10
# Out:
# C:\Users\Hira singh\AppData\Local\Temp\ipykernel_24964\4069860292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hamlet['decade']=(Hamlet['year'] // 10) * 10

# %%
decade_counts =Hamlet ['decade'].value_counts().sort_index()

# %%
decade_counts.plot(kind='bar',xlabel='Decade',ylabel= 'Number',title ='Hamlet_character')
plt.show()

# %% [markdown]
# ### What are the 11 most common character names in movie history?

# %%
character_counts = cast['character'].value_counts()

# %%
common_character=character_counts.head(11)
print(common_character)
# Out:
# Himself        8438
# Policeman      3043
# Doctor         2799
# Extra          2765
# Reporter       2692
# Townsman       2634
# Bartender      2414
# Waiter         2296
# Henchman       2140
# Dancer         2002
# Party Guest    1905
# Name: character, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Herself" in film history?

# %%
Herself_credit=cast[cast['character']=='Herself']

# %%
Herself_credit= Herself['character'].value_counts().head(10)
print(Herself_credit)
# Out:
# Herself    30
# Name: character, dtype: int64

# %%
name='name'
Herself_credit = Herself['name'].value_counts().head(10)
print(Herself_credit)
# Out:
# Etta Baker            1
# Ren? Biaggi           1
# Rebecca Hudson        1
# Faustine Hudson       1
# Jan Hrkach            1
# Krystian Hill         1
# Ali Harter            1
# Heather (II) Hardy    1
# Megan Grandall        1
# Jeff (II) Grace       1
# Name: name, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Himself" in film history?

# %%
Himself_credit=cast[cast['character']=='Himself']

# %%
Himself_credit = Himself_credit['name'].value_counts().head(10)
print(Himself_credit)
# Out:
# Adolf Hitler         99
# George W. Bush       23
# Winston Churchill    23
# Bill Clinton         20
# Muhammad Ali         17
# Billy Graham         15
# Amitabh Bachchan     13
# Jimmy Carter         13
# Walter Cronkite      11
# Fidel Castro         11
# Name: name, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1945?

# %%
movies_1945=cast[cast['year']==1945]

# %%
most_appeared_1945_actor=movies_1945['name'].value_counts().idxmax()
print(most_appeared_1945_actor)
# Out:
# sam (ii) harris

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1985?

# %%
movies_1985=cast[cast['year']==1985]

# %%
most_appeared_1985_actor=movies_1985['name'].value_counts().idxmax()
print(most_appeared_1985_actor)
# Out:
# raj babbar

# %% [markdown]
# ### Plot how many roles Mammootty has played in each year of his career.

# %%
Mammootty_roles=cast[cast['name']=='Mammootty']

# %%
roles_year=Mammootty_roles.groupby('year').size()

# %%
plt.figure(figsize=(10,6))

# %%
roles_year.plot(kind='bar',xlabel='year',ylabel= 'roles',title ='Roles played')
plt.show() #no data available show in the
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 roles_year.plot(kind='bar',xlabel='year',ylabel= 'roles',title ='Roles played')
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
if not Mammootty_roles.empty:
    roles_year=Mammootty_roles.groupby('year').size()
    plt.figure(figsize=(10,6))
    plt.plot(roles_year.index,roles_year.values,markers='o',linestyle='--')
    plt.title('Roles Played')
    plt.xlabel=('year')
    plt.ylabel=('roles')
    plt.show()
else:
    print("Data not available")
# Out:
# Data not available

# %% [markdown]
# ### What are the 10 most frequent roles that start with the word "Science"?

# %%
Science_roles=cast[cast['character'].str.startswith('Science')]

# %%
character='character'
Science_roles=Science_roles['character'].value_counts().head(10)
print(Science_roles)
# Out:
# Science Teacher              17
# Science Student               7
# Science Club Member           4
# Science Fair Kid              2
# Science Kid                   2
# Science Reporter              2
# Science Performer 3           1
# Science Fair Student          1
# Science                       1
# Science Fair Crowd Member     1
# Name: character, dtype: int64

# %% [markdown]
# ### Plot the n-values of the roles that Judi Dench has played over her career.

# %%
Judi_Dench= cast[cast['name']=='Judi Dench']

# %%
if not Judi_Dench.empty:
    plt.figure(figsize=(10,6))
    plt.plot(Judi_Dench['year'],Judi_Dench['n'],marker='o',linestyle='--')
    plt.title('Roles Played')
    plt.xlabel=('year')
    plt.ylabel=('roles')
    plt.show()
else:
    print('Not Available')
# Out:
# Not Available

# %% [markdown]
# ### Plot the 'n' value Cary Grant roles through his career

# %%
Cary_Grant=cast[cast['name']=='Cary Grant']

# %%
if not Cary_Grant.empty:
    plt.figure(figsize=(10,8))
    plt.plot(Cary_Grant['year'],Cary_Grant['n'],marker='*',linestyle='--')
    plt.title('Roles Played')
    plt.xlabel=('year')
    plt.ylabel=('roles')
    plt.show()
else:
    print('Not Available')

# %% [markdown]
# ### Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %%
Sidney_Poitier =cast[cast['name']=='Sidney Poitier '] # same as above question but data is not available

# %%
if not Sidney_Poitier.empty:
    plt.figure(figsize=(15,7))
    plt.plot(Sidney_Poitier['year'],Sidney_Poitier['n'],marker='+',linestyle='*')
    plt.title('Roles Played')
    plt.xlabel=('year')
    plt.ylabel=('roles')
    plt.show()
else:
    print('Not Available')
# Out:
# Not Available

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
leading_roles= cast[(cast['year']>=1950) & (cast['year']<=1950)]

# %%
leading_roles_counts= leading_roles[leading_roles['n']==1]['type'].value_counts()

# %%
print("actor:",leading_roles_counts.get('actor',0))
print("actresses:",leading_roles_counts.get('actor',0))
# Out:
# actor: 281
# actresses: 281

# %% [markdown]
# In data not mention separetly about actor and actresses

# %% [markdown]
# ### How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
supporting_roles= cast[(cast['year']>=1950) & (cast['year']<=1959)]

# %%
supporting_roles_counts= supporting_roles[supporting_roles['n']==2]['type'].value_counts()

# %%
print("actor:",supporting_roles_counts.get('actor',0))
print("actresses:",supporting_roles_counts.get('actor',0))
# Out:
# actor: 2080
# actresses: 2080
